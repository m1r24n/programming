# %%
from fractions import Fraction
value1=10
value2=10.56
value3=3-3j
value4=Fraction(1,2)
print(value1, type(value1))
print(value2, type(value2))
print(value3, type(value3))
print(float(value4 * 13))
# Out:
# 10 <class 'int'>
# 10.56 <class 'float'>
# (3-3j) <class 'complex'>
# 6.5
